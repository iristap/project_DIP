# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import sys
from PIL import Image

# %%
def Grayscale(img):
    h = img.shape[0]
    w = img.shape[1]
    img_out = img_out = np.full((h,w,3),0,dtype=np.uint8)
    for i in range(h):
        for j in range(w):
            img_out[i][j][0] = img_out[i][j][1] = img_out[i][j][2] = img[i][j][1]
    return img_out

# %%
img_bgr = cv2.imread("./B/b10_11.jpg")
img_bgr=cv2.resize(img_bgr, (200,200))
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
imgGray = Grayscale(img_rgb)

# %%
def Histogram(img): #check
    img_rgb = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)
    img_rgb = img.copy()
    h = img_rgb.shape[0]
    w = img_rgb.shape[1]
    
    
    # count of intensity value
    count = np.full(256,0,dtype=int)
         
    for i in range(h):
        for j in range(w):
            if img_rgb[i][j][0] != 0: 
                intensity = img_rgb[i, j]
                count[intensity] += 1
    min = count[100]
    minIn = 100
    for k in range(100,120):
       if min>count[k] and k!=0:
           min = count[k]
           minIn = k

    print(minIn)
    print(min)

    return np.arange(256), count, minIn

# %%
def median_V2(lst):
    sortedLst = sorted(lst)
    lstLen = len(lst)
    index = (lstLen - 1) // 2
   
    if (lstLen % 2):
        return sortedLst[index]
    else:
        return (sortedLst[index] + sortedLst[index + 1])/2.0

size = 11
mask = np.full((size,size),1,dtype=np.uint16)
list = []
imH = imgGray.shape[0]
imW = imgGray.shape[1]
filterH = mask.shape[0]
filterW = mask.shape[1]
filterHCenter = int((filterH+1)/2)-1
filterWCenter = int((filterW+1)/2)-1

sumWeightMask = 0
for i in range(filterH):
    for j in range(filterW):
        sumWeightMask = sumWeightMask + mask[i][j]

imgOut = np.full((imH,imW,3),0,dtype=np.uint16)
for i in range(imH):
    for j in range(imW):
        sumMask = 0
        for fi in range(filterH):
            for fj in range(filterW):
                posX = i + (fi-filterHCenter)
                posY = j + (fj-filterWCenter)
                if posX < 0 :
                    posX = 0
                elif posX >= imH :
                    posX = imH - 1
                if posY <0:
                    posY = 0
                elif posY >= imW :
                    posY = imW - 1 
                list.append(imgGray[posX][posY][1])
        imgOut[i][j][0] = imgOut[i][j][1] = imgOut[i][j][2] = median_V2(list)
        list = []

print(sumWeightMask)
plt.imshow(imgGray)
plt.show()
plt.imshow(imgOut)
plt.show()

intensity, value, minIn  = Histogram(imgOut)
plt.bar(intensity,value)
plt.title("HISTROGRAM")
plt.show()
# Out:
# 121
# 102
# 38

# %%
def THRESHOLD(img,value):
    img_rgb = img.copy()
    h =  img_rgb.shape[0]
    w = img_rgb.shape[1]
    img_out = np.zeros((h, w, 3), dtype=np.uint8)
    for i in range(h):
        for j in range(w):
            if img_rgb[i][j][0] >= value:
                img_out[i][j][0] = img_out[i][j][1] = img_out[i][j][2] = 255 #white
            else:
                img_out[i][j][0] = img_out[i][j][1] = img_out[i][j][2] = 0 #black
    return img_out
imgOut = THRESHOLD(imgOut,minIn)
# plt.imshow(imgOut)
# plt.show()

# %%
y = imgOut.shape[0]
x = imgOut.shape[1]
plt.imshow(imgOut)
plt.show()
C = 1.3
for i in range(y):
    for j in range(x):
        imgOut[i][j][0] = 255 - imgOut[i][j][0]
        imgOut[i][j][1] = 255 - imgOut[i][j][1]
        imgOut[i][j][2] = 255 - imgOut[i][j][2]
plt.imshow(imgOut)
plt.show()

# %%
def print_crop(num,img):
    for x in range(num):
        print(f"รูปที่ {x+1}")
        print(f"ขนาด {object_list[x]['Size']}")
        r = object_list[x]['Color'][0]
        g = object_list[x]['Color'][1]
        b = object_list[x]['Color'][2]
        crop = imgOut[object_list[x]['X_min']:object_list[x]['X_max']+1 , object_list[x]['Y_min']:object_list[x]['Y_max']+1]
        realimg = img[object_list[x]['X_min']:object_list[x]['X_max']+1 , object_list[x]['Y_min']:object_list[x]['Y_max']+1]
        copy = crop.copy()
        h = copy.shape[0]
        w = copy.shape[1]
        pixel = 0
        
        for i in range(h):
            for j in range(w):
                if copy[i][j][0] != r and copy[i][j][1] != g and copy[i][j][2] != b :
                    copy[i][j][0] = copy[i][j][1] = copy[i][j][2] = 255
                else:
                    pixel = pixel + realimg[i][j][0]
                
        pixel_object.append({
            'object': object_list[x],
            'pixel': pixel
        })
        plt.imshow(copy)
        plt.show()



def labeling_findmax(img,numCrop):
    def recursive(x, y, color,xmin,xmax,ymin,ymax,size): 
        if 0 <= x < len(img) and 0 <= y < len(img[0]) and img[x][y][0] == 0: 
            if x <= xmin:
                xmin = x
            if x >= xmax:
                xmax = x
            if y <= ymin:
                ymin = y
            if y >= ymax:
                ymax = y
            size = size + 1
            img[x][y][0] = color[0]
            img[x][y][1] = color[1]
            img[x][y][2] = color[2]
            xmin, xmax, ymin, ymax, size = recursive(x + 1, y, color, xmin, xmax, ymin, ymax, size)  # ขวา 
            xmin, xmax, ymin, ymax, size = recursive(x - 1, y, color, xmin, xmax, ymin, ymax, size)  # ซ้าย
            xmin, xmax, ymin, ymax, size = recursive(x, y + 1, color, xmin, xmax, ymin, ymax, size)  # บน
            xmin, xmax, ymin, ymax, size = recursive(x, y - 1, color, xmin, xmax, ymin, ymax, size)  # ล่าง
        return xmin,xmax,ymin,ymax,size
            
    
    h = img.shape[0]
    w = img.shape[1]
    counting = 0
    xmax  = ymax = size = 0
    xmin = h
    ymin = w
    for i in range(h):
        for j in range(w):
            if img[i][j][0] != 0 and img[i][j][0] != 255:
                    xmax  = ymax = size = 0
                    xmin = h
                    ymin = w
            if img[i][j][0] == 0 and img[i][j][1] == 0 and img[i][j][2] == 0:
                r = int(np.random.uniform(1,255))
                g = int(np.random.uniform(1,255))
                b = int(np.random.uniform(1,255))
                color = [r,g,b]
                xmin,xmax,ymin,ymax,size = recursive(i, j,color,xmin,xmax,ymin,ymax,size)
                if size < 100:
                    continue
                if xmin == 0:
                    continue
                if ymin == 0:
                    continue
                if xmax == h-1:
                    continue
                if ymax == w-1:
                    continue
                
                counting = counting + 1
                object_list.append({
                    'Size': size,
                    'X_min': xmin,
                    'X_max': xmax,
                    'Y_min': ymin,
                    'Y_max': ymax,
                    'Color': color
                })
                # print(f"size = {size} xmin = {xmin} xmax = {xmax} ymin = {ymin} ymax = {ymax}")
    
    print(f"จำนวนวัตถุ = {counting}")
    return counting
    
pixel_object = []
sys.setrecursionlimit(90000)
counting = 0
size = 0
check = 0
xmin = xmax = ymin = ymax = 0
object_list = []
numCrop = 3
counting = labeling_findmax(imgOut,numCrop)

def myFunc(e):
  return e['Size']

# print(object_list)
object_list.sort(reverse=True,key=myFunc)
print(object_list)
# try:
#     print(f"Max 3 area object No.1 = {object_list[0]['Size']} No.2 = {object_list[1]['Size']} No.3 = {object_list[2]['Size']}")
# except:
#     print('out of range')


print_crop(counting,imgGray)

plt.imshow(imgOut)
plt.show()
# Out:
# จำนวนวัตถุ = 1
# [{'Size': 2215, 'X_min': 46, 'X_max': 117, 'Y_min': 96, 'Y_max': 175, 'Color': [160, 67, 230]}]
# รูปที่ 1
# ขนาด 2215

# %%
# print(pixel_object)

# for i in range(counting):
#     print(f"รูปที่ {i+1} มีพิกเซล = {pixel_object[i]['pixel']}")
#     avg = pixel_object[i]['pixel'] / object_list[i]['Size']
#     print(f"ค่าเฉลี่ย = {avg}")

# %%
import cv2

num = 3
# plt.imshow(img_bgr)
# plt.show()
imgtest = img_bgr.copy()


for x in range(counting):
    print(f"รูปที่ {x+1}")
    print(f"ขนาด {object_list[x]['Size']}")

    crop = img_bgr[object_list[x]['X_min']:object_list[x]['X_max']+1 , object_list[x]['Y_min']:object_list[x]['Y_max']+1]
    imH = crop.shape[0]
    imW = crop.shape[1]
    sum = 0
    for i in range(imH):
        for j in range(imW):
            sum = sum + crop[i][j][1]

    answer = ''
    avg = sum/(imH*imW)
    # if (avg > 115):
    #     answer = "MALIGNANT"
    # else:
    #     answer = "BENIGN"
    if imH < 25.5 :
        answer = "MALIGNANT"
    else:
        if imW >= 68.5:
            answer = "BENIGN"
        else:
            if avg < 110.18:
                answer = "MALIGNANT"
            else:
                if y < 32.5:
                    answer = "BENIGN"
                else:
                    if avg < 120.24:
                        answer = "BENIGN"
                    else:
                        if imH < 31.5:
                            answer = "BENIGN"
                        else:
                            answer = "MALIGNANT"



    print(answer , avg , "กว้าง = " , object_list[x]['X_max']+1 - object_list[x]['X_min'] ,"ยาว = ", object_list[x]['Y_max']+1 - object_list[x]['Y_min'])
    # print(answer)
    


    plt.imshow(crop)
    plt.show()
# Out:
# รูปที่ 1
# ขนาด 2215
# BENIGN 87.79166666666667 กว้าง =  72 ยาว =  80

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
# กำหนดข้อมูล
data = {
    'ความเข้มแสง': [96.16471460340993, 107.47806233869366, 110.57202011239278, 119.79478260869566, 130.01270417422867,
                   127.05925925925926, 133.08651026392963, 110.55075918079096, 124.29990966576332, 87.79166666666667,
                   130.56067251461988, 128.67857142857142, 109.63634453781512, 120.69459219858156, 138.5639097744361,
                   126.84833333333333, 135.81632653061226, 109.79617117117117, 104.13078118927322, 109.50970632155301],
    'กว้าง': [95, 73, 69, 46, 57, 45, 31, 118, 27, 72, 38, 36, 70, 96, 19, 24, 21, 72, 83, 82],
    'ยาว': [71, 69, 49, 50, 29, 21, 22, 96, 41, 80, 36, 42, 68, 47, 14, 25, 14, 37, 62, 49],
    'label': ['BENIGN'] * 10 + ['MALIGNANT'] * 10
}
df = pd.DataFrame(data)

# %%
# แบ่งข้อมูลเป็น Features (X) และ Labels (y)
X = df[['ความเข้มแสง', 'กว้าง', 'ยาว']]
y = df['label']

# แบ่งข้อมูลเป็นชุดฝึกและชุดทดสอบ
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

# %%
# สร้างโมเดล Decision Tree Classifier
clf = DecisionTreeClassifier()

# ฝึกโมเดลด้วยชุดข้อมูลฝึก
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# ทำนายข้อมูลทดสอบ
y_pred = clf.predict(X_test)

# คำนวณความแม่นยำ
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# แสดงโครงสร้างของ Decision Tree
plt.figure(figsize=(10, 7))
plot_tree(clf, feature_names=X.columns, class_names=['BENIGN', 'MALIGNANT'], filled=True)
plt.show()
# Out:
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3657 (\N{THAI CHARACTER MAI THO}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# c:\Users\PlsDontBroken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\tree\_export.py:664: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from current font.
#   ann.update_bbox_position_size(renderer)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3585 (\N{THAI CHARACTER KO KAI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3623 (\N{THAI CHARACTER WO WAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3657 (\N{THAI CHARACTER MAI THO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3634 (\N{THAI CHARACTER SARA AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3591 (\N{THAI CHARACTER NGO NGU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3588 (\N{THAI CHARACTER KHO KHWAI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3617 (\N{THAI CHARACTER MO MA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3648 (\N{THAI CHARACTER SARA E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3586 (\N{THAI CHARACTER KHO KHAI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3649 (\N{THAI CHARACTER SARA AE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3626 (\N{THAI CHARACTER SO SUA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\PlsDontBroken\AppData\Roaming\Python\Python312\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 3618 (\N{THAI CHARACTER YO YAK}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import csv

data = [
    [96.16471460340993, 95, 71, "BENIGN"],
    [107.47806233869366, 73, 69, "BENIGN"],
    [110.57202011239278, 69, 49, "BENIGN"],
    [119.79478260869566, 46, 50, "BENIGN"],
    [130.01270417422867, 57, 29, "BENIGN"],
    [127.05925925925926, 45, 21, "BENIGN"],
    [133.08651026392963, 31, 22, "BENIGN"],
    [110.55075918079096, 118, 96, "BENIGN"],
    [124.29990966576332, 27, 41, "BENIGN"],
    [87.79166666666667, 72, 80, "BENIGN"],
    [130.56067251461988, 38, 36, "MALIGNANT"],
    [128.67857142857142, 36, 42, "MALIGNANT"],
    [109.63634453781512, 70, 68, "MALIGNANT"],
    [120.69459219858156, 96, 47, "MALIGNANT"],
    [138.5639097744361, 19, 14, "MALIGNANT"],
    [126.84833333333333, 24, 25, "MALIGNANT"],
    [135.81632653061226, 21, 14, "MALIGNANT"],
    [109.79617117117117, 72, 37, "MALIGNANT"],
    [104.13078118927322, 83, 62, "MALIGNANT"],
    [109.50970632155301, 82, 49, "MALIGNANT"]
]

# กำหนดชื่อไฟล์ CSV
csv_filename = "data.csv"

# เขียนข้อมูลลงในไฟล์ CSV
with open(csv_filename, 'w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    # เขียนหัวข้อคอลัมน์
    writer.writerow(["ความเข้มแสง", "กว้าง", "ยาว", "label"])
    # เขียนข้อมูล
    writer.writerows(data)

print("ไฟล์ CSV ถูกสร้างเรียบร้อยแล้ว:", csv_filename)
# Out:
# ไฟล์ CSV ถูกสร้างเรียบร้อยแล้ว: data.csv
